# %%
# import roofline as rl
# color choices["darkviolet","darkmagenta","indigo","maroon","darkblue","navy","darkgreen","darkslategrey", "teal","olive", "saddlebrown","black"]

# %%
# Example1

import roofline as rl
savefile = "myroof_0.png"
fnames = ["LBM Baseline", "Collision Baseline", "Momentum Baseline"] 
op_types =   ["flop"]
byte_types = ["load"]

datafile = "TimingData_roofline.csv"

mycolors = ["black","black","black","black","black","black","black","black","black"]
rl.plot_zen3(9, fnames, op_types, byte_types, mycolors, savefile, datafile)

# %%
import roofline as rl
# Example 2
savefile = "myroof2.png"
op_types =   ["flop","iop","both"]
byte_types = ["load","store","both"]

fnames = ["LBM Baseline"]
# mycolors = ["brown","orange","black","brown","orange","black","brown","orange","black"]
mycolors = ["black","black","black","saddlebrown","saddlebrown","saddlebrown","darkslategrey","darkslategrey","darkslategrey"]
datafile = "TimingData_roofline.csv"
rl.plot_coffee(27, fnames, op_types, byte_types, mycolors, savefile, datafile)

# %%
# https://en.wikichip.org/wiki/intel/microarchitectures/kaby_lake
# Scheduler Ports Designation
# Port 0	Integer/Vector Arithmetic, Multiplication, Logic, Shift, and String ops
# FP Add, Multiply, FMA
# Integer/FP Division and Square Root
# AES Encryption
# Branch2
# Port 1	Integer/Vector Arithmetic, Multiplication, Logic, Shift, and Bit Scanning
# FP Add, Multiply, FMA
# Port 5	Integer/Vector Arithmetic, Logic
# Vector Permute
# x87 FP Add, Composite Int, CLMUL
# Port 6	Integer Arithmetic, Logic, Shift
# Branch
# Port 2	Load, AGU
# Port 3	Load, AGU
# Port 4	Store, AGU
# Port 7	AGU

# %%
# intel i9-9880H
# intel coffeeLake
# https://en.wikichip.org/wiki/intel/microarchitectures/coffee_lake
# Scheduler Ports Designation
# Port 0	Integer/Vector Arithmetic, Multiplication, Logic, Shift, and String ops
# FP Add, Multiply, FMA
# Integer/FP Division and Square Root
# AES Encryption
# Branch2
# Port 1	Integer/Vector Arithmetic, Multiplication, Logic, Shift, and Bit Scanning
# FP Add, Multiply, FMA
# Port 5	Integer/Vector Arithmetic, Logic
# Vector Permute
# x87 FP Add, Composite Int, CLMUL
# Port 6	Integer Arithmetic, Logic, Shift
# Branch
# Port 2	Load, AGU
# Port 3	Load, AGU
# Port 4	Store
# Port 7	AGU

# %%
# The AMD Ryzen 7 PRO 6850U supports up to 64 GB memory in up to 2 (Dual Channel) memory channels. This results in a maximum memory bandwidth of 76.8 GB/s.
# Memory type: 	Memory bandwidth:
# LPDDR5-6400
# DDR5-4800
# 	51.2 GB/s
# 76.8 GB/s
# L1
# wikipedia zen3 All cache read and write operations are done at 32 bytes per cycle.



# peak flops with fma: 
# add on p01   2
# mul and fma 2(x2) on p23
# 6...
# peak iops 4 per cycle ..

# %%
# all 3  processor ca maximall use avx2 256but
# meaning 8byte = 64 bit double  -> x4
#  4byte 32 bit interger > x8
